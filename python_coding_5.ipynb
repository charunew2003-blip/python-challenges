# %%
Create a dictionary with student names as keys and their grades as values.


student={"divya":95,
         "vooha":90,
         "kavitha":92,
         "sabnam":85,
         "banu":89
         }
print(student)

{'divya': 95, 'vooha': 90, 'kavitha': 92, 'sabnam': 85, 'banu': 89}
Allow the user to add or update grades for at least 3 students.


student["priya"]=65
student.update({"vindhiya":86})
student["swathi"]=69
print(student)

{'divya': 95, 'vooha': 90, 'kavitha': 92, 'sabnam': 85, 'banu': 89, 'priya': 65, 'vindhiya': 86, 'swathi': 69}
Create a set of hobbies and allow the user to input at least 3 hobbies.


hobbie1=input("Enter the hoppie1:")
hobbie2=input("Enter the hoppie2:")
hobbie3=input("Enter the hoppie3:")
hobbies={hobbie1,hobbie2,hobbie3}
print(hobbies)

Enter the hoppie1:chess
Enter the hoppie2:carrom
Enter the hoppie3:cricket
{'carrom', 'cricket', 'chess'}
Convert the set of hobbies into a frozenset and display it.


hobbies_frozen=frozenset(hobbies)
print(hobbies_frozen)

frozenset({'carrom', 'cricket', 'chess'})
