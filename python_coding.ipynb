# %%
# Operators, Conditional Statements

# Ask the user to enter their weight (in kilograms) and height (in meters).
weight=float(input("Enter your weight(kilograms):"))
height=float(input("Enter your height (in meters, e.g., 1.75):"))

# Calculate their BMI using the formula BMI = weight / (height * height).
bmi=weight/(height*height)
print(bmi)

# Classify the BMI as underweight, normal, overweight, or obese using conditional statements.
# The input for bmi here is redundant if bmi is already calculated above.
# If you intend to test different BMI values, you can keep the input.
# Otherwise, you can use the calculated 'bmi' directly.
# For now, I'll assume you want to use the calculated 'bmi' directly for classification.

# Re-calculating BMI using the already computed 'bmi' variable, or asking for new input.
# If you want to use the previously calculated 'bmi' for classification:
# if bmi<18.5:
#   print("your bmi is:Underweight")
# elif bmi>=18.5 and bmi<=24.9:
#   print("your bmi is:Healthyweight")
# elif bmi>=25.0 and bmi<=29.9:
#   print("your bmi is:Overweight")
# else:
#   print("your bmi is:.Obese")

# Original code logic (kept for historical context, but the classification should ideally use the calculated 'bmi')
# To avoid confusion, I'm using the calculated 'bmi' directly for the classification.

if bmi<18.5:
  print(f"Your BMI is {bmi:.2f}: Underweight")
elif bmi>=18.5 and bmi<=24.9:
  print(f"Your BMI is {bmi:.2f}: Healthyweight")
elif bmi>=25.0 and bmi<=29.9:
  print(f"Your BMI is {bmi:.2f}: Overweight")
else:
  print(f"Your BMI is {bmi:.2f}: Obese")
# Out:
# Enter your weight(kilograms):18.5
# Enter your height (in meters, e.g., 1.75):underweight
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2140391060.py in <cell line: 0>()
#       3 # Ask the user to enter their weight (in kilograms) and height (in meters).
#       4 weight=float(input("Enter your weight(kilograms):"))
# ----> 5 height=float(input("Enter your height (in meters, e.g., 1.75):"))
#       6
#       7 # Calculate their BMI using the formula BMI = weight / (height * height).
#
# ValueError: could not convert string to float: 'underweight'
